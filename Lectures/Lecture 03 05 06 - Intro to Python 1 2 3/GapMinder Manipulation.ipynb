# %% [markdown]
# # Splitting GapMinder

# %%
import pandas as pd

# %%
gm = pd.read_csv('gapminder.csv')

# %%
gm.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987  ...    pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
gm.columns
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %%
gm_gdp = gm.loc[:, gm.columns.str.startswith('co') | gm.columns.str.startswith('gdp')]

# %%
gm_life = gm.loc[:, gm.columns.str.startswith('co') | gm.columns.str.startswith('life')]

# %%
gm_pop = gm.loc[:, gm.columns.str.startswith('co') | gm.columns.str.startswith('pop')]

# %% [markdown]
# ## Adjusting data

# %%
# Leave GDPc alone
gm_gdp.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# ...

# %%
# Leave life Expecatancy Alone
gm_life.tail()
# Out:
#     continent         country  lifeExp_1952  lifeExp_1957  lifeExp_1962  \
# 137    Europe     Switzerland        69.620        70.560        71.320
# 138    Europe          Turkey        43.585        48.079        52.098
# 139    Europe  United Kingdom        69.180        70.420        70.760
# 140   Oceania       Australia        69.120        70.330        70.930
# 141   Oceania     New Zealand        69.390        70.260        71.240
#
#      lifeExp_1967  lifeExp_1972  lifeExp_1977  lifeExp_1982  lifeExp_1987  \
# 137        72.770        73.780        75.390        76.210        77.410
# 138        54.336        57.005        59.507        61.036        63.108
# 139        71.360        72.010        72.760        74.040        75.007
# 140        71.100        71.930        73.490        74.740        76.320
# 141        71.520        71.890        72.220        73.840        74.320
#
#      lifeExp_1992  lifeExp_1997  lifeExp_2002  lifeExp_2007
# ...

# %%
gm_pop.head()
# Out:
#   continent       country   pop_1952    pop_1957    pop_1962    pop_1967  \
# 0    Africa       Algeria  9279525.0  10270856.0  11000948.0  12760499.0
# 1    Africa        Angola  4232095.0   4561361.0   4826015.0   5247469.0
# 2    Africa         Benin  1738315.0   1925173.0   2151895.0   2427334.0
# 3    Africa      Botswana   442308.0    474639.0    512764.0    553541.0
# 4    Africa  Burkina Faso  4469979.0   4713416.0   4919632.0   5127935.0
#
#      pop_1972    pop_1977    pop_1982    pop_1987    pop_1992    pop_1997  \
# 0  14760787.0  17152804.0  20033753.0  23254956.0  26298373.0  29072015.0
# 1   5894858.0   6162675.0   7016384.0   7874230.0   8735988.0   9875024.0
# 2   2761407.0   3168267.0   3641603.0   4243788.0   4981671.0   6066080.0
# 3    619351.0    781472.0    970347.0   1151184.0   1342614.0   1536536.0
# 4   5433886.0   5889574.0   6634596.0   7586551.0   8878303.0  10352843.0
#
#    pop_2002  pop_2007
# 0  31287142  33333216
# 1  10866106  12420476
# ...

# %%
gm_pop = pd.wide_to_long(gm_pop, stubnames = 'pop', i = ['country', 'continent'], j = 'year', sep = '_').reset_index()

# %%
gm_pop.columns = gm_pop.columns.str.upper()

# %%
gm_pop.head()
# Out:
#    COUNTRY CONTINENT  YEAR         POP
# 0  Algeria    Africa  1952   9279525.0
# 1  Algeria    Africa  1957  10270856.0
# 2  Algeria    Africa  1962  11000948.0
# 3  Algeria    Africa  1967  12760499.0
# 4  Algeria    Africa  1972  14760787.0

# %% [markdown]
# ## Saving

# %%
gm_gdp.to_csv('gapminder GDPc.csv', index = False)

# %%
gm_life.to_csv('gapminder life expectancy.csv', index = False)

# %%
gm_pop.to_csv('gapminder population.csv', index = False)
